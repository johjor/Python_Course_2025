# %% [markdown]
# # Action-movies by year
# In IMDb the movies are sorted by genre e.g. action, crime, comedie or romance. Each movie in the dataset has usually two to three different genres - making it easier to sort out what type of movie it is.
#
# ### Objective
# * **Goal:** Sort out the action movies (movies including action as a genre) and create a linegraph to illustrate the action-movies by year.
# * **Hypothesis:** The movie genre "Action" have become more popular over the decades
#
# *Description of set up is written in Popular review*
#
# First i set up the data, making it easy and understandable to create the visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Specify the correct path to the CSV file with the name of the CSV file
dataset_path = "../data/merged_dataset.csv"

# Load the dataset into a pandas DataFrame
df = pd.read_csv(dataset_path)

# %%
df #Check if the dataframe work
# Out:
#                                                    name  year movie_rated  \
# 0                                             Inception  2010       PG-13
# 1     The Lord of the Rings: The Fellowship of the Ring  2001       PG-13
# 2         The Lord of the Rings: The Return of the King  2003       PG-13
# 3                                 The Dark Knight Rises  2012       PG-13
# 4                 The Lord of the Rings: The Two Towers  2002       PG-13
# ...                                                 ...   ...         ...
# 1495                                           Catch-22  1970           R
# 1496                                     The Great Raid  2005           R
# 1497                                Saints and Soldiers  2003       PG-13
# 1498                                          Stop-Loss  2008           R
# 1499                                          The Alamo  2004       PG-13
#
#      run_length                       genres            release_date  rating  \
# 0      2h 28min  Action; Adventure; Sci-Fi;       16 July 2010 (USA)     8.8
# 1      2h 58min   Action; Adventure; Drama;   19 December 2001 (USA)     8.8
# 2      3h 21min  Adventure; Drama; Fantasy;   17 December 2003 (USA)     8.9
# 3      2h 44min          Action; Adventure;       20 July 2012 (USA)     8.4
# 4      2h 59min  Adventure; Drama; Fantasy;   18 December 2002 (USA)     8.7
# ...         ...                          ...                     ...     ...
# 1495    2h 2min         Comedy; Drama; War;       24 June 1970 (USA)     7.1
# 1496   2h 12min         Action; Drama; War;     12 August 2005 (USA)     6.7
# 1497   1h 30min         Action; Drama; War;      25 March 2005 (USA)     6.7
# 1498   1h 52min                 Drama; War;      28 March 2008 (USA)     6.4
# 1499   2h 17min        Drama; History; War;       9 April 2004 (USA)     6.0
#
#       num_raters  num_reviews
# 0        1981675         3820
# 1        1609165         5365
# 2        1593859         3681
# 3        1470329         2979
# 4        1440188         2559
# ...          ...          ...
# 1495       21424          145
# 1496       20965          194
# 1497       19730          163
# 1498       19456          102
# 1499       19290          306
#
# [1500 rows x 9 columns]

# %%
#I want to check which data types the columns are
print(df.dtypes)
#This is to check if e.g. year is a numeric format.
# Out:
# name             object
# year              int64
# movie_rated      object
# run_length       object
# genres           object
# release_date     object
# rating          float64
# num_raters        int64
# num_reviews       int64
# dtype: object

# %%
#I want to take a look at the different genres to make sure that "Action" is in there.
unique_genres = df['genres'].unique()
print(unique_genres)
# Out:
# ['Action; Adventure; Sci-Fi; ' 'Action; Adventure; Drama; '
#  'Adventure; Drama; Fantasy; ' 'Action; Adventure; '
#  'Adventure; Drama; Sci-Fi; ' 'Adventure; Drama; War; '
#  'Action; Adventure; Fantasy; ' 'Action; Adventure; Comedy; '
#  'Adventure; Comedy; Sci-Fi; ' 'Animation; Adventure; '
#  'Animation; Adventure; Comedy; ' 'Animation; Adventure; Drama; '
#  'Adventure; Fantasy; ' 'Adventure; Comedy; Crime; '
#  'Animation; Action; Adventure; ' 'Action; Adventure; Thriller; '
#  'Action; Adventure; Mystery; ' 'Action; Adventure; Horror; '
#  'Adventure; Sci-Fi; ' 'Adventure; Mystery; Sci-Fi; '
#  'Adventure; Biography; Drama; ' 'Adventure; Thriller; '
#  'Animation; Comedy; ' 'Animation; Fantasy; '
#  'Animation; Adventure; Fantasy; ' 'Animation; Drama; '
#  'Animation; Drama; War; ' 'Animation; Action; Comedy; '
#  'Animation; Comedy; Fantasy; ' 'Animation; Drama; Fantasy; '
#  'Animation; Comedy; Drama; ' 'Animation; Drama; Sci-Fi; '
#  'Biography; Drama; History; ' 'Biography; Crime; Drama; '
#  'Biography; Drama; ' 'Biography; Comedy; Drama; '
#  'Biography; Drama; Music; ' 'Biography; Drama; Thriller; '
#  'Action; Biography; Drama; ' 'Biography; Drama; Sport; '
#  'Biography; Drama; Romance; ' 'Action; Adventure; Biography; '
#  'Biography; Comedy; Crime; ' 'Action; Biography; Comedy; ' 'Comedy; '
#  'Comedy; Romance; ' 'Action; Crime; Drama; ' 'Crime; Drama; '
#  'Crime; Drama; Mystery; ' 'Crime; Drama; Thriller; '
#  'Crime; Drama; Fantasy; ' 'Action; Crime; Thriller; '
#  'Crime; Mystery; Thriller; ' 'Comedy; Crime; ' 'Crime; Drama; Sci-Fi; '
#  'Crime; Thriller; ' 'Comedy; Crime; Sport; ' 'Action; Comedy; Crime; '
#  'Action; Crime; Mystery; ' 'Comedy; Crime; Drama; '
#  'Action; Crime; Fantasy; ' 'Action; Adventure; Crime; '
#  'Action; Crime; Sci-Fi; ' 'Action; Crime; Horror; ' 'Drama; '
#  'Drama; Romance; ' 'Drama; Western; ' 'Drama; War; '
#  'Drama; Mystery; Sci-Fi; ' 'Action; Drama; Sci-Fi; '
#  'Comedy; Drama; Sci-Fi; ' 'Drama; Mystery; Thriller; '
#  'Drama; Romance; Sci-Fi; ' 'Drama; Horror; ' 'Drama; Sci-Fi; Thriller; '
#  'Action; Drama; ' 'Drama; Music; ' 'Drama; Thriller; '
#  'Comedy; Drama; Romance; ' 'Drama; Sport; ' 'Drama; Fantasy; War; '
#  'Drama; Mystery; War; ' 'Drama; Fantasy; Romance; ' 'Comedy; Drama; '
#  'Action; Drama; War; ' 'Action; Comedy; War; ' 'Comedy; Drama; War; '
#  'Comedy; War; ' 'Biography; Drama; War; ' 'Action; War; '
#  'Action; Adventure; War; ' 'Drama; Horror; War; '
#  'Adventure; Comedy; War; ' 'Adventure; History; War; '
#  'Crime; Drama; War; ' 'Drama; War; Western; ' 'Drama; Sport; War; '
#  'Thriller; War; ']

# %% [markdown]
# ### Sort out "action" in "genre"

# %%
#Action is included in several genres.
#I want to look at "action" and "year". 

# Create a datarame (action_movies) that only includes movies classified under the "Action" genre.
action_movies = df[df["genres"].str.contains('Action', na=False)] #Selecting genres column from dsatafram, check if the column contains the word action, na=False, ensure that missing values are treated as False.
action_movies_per_year = action_movies.groupby('year').size() #Group the action movies by year

# %% [markdown]
# ### Create a line graph
# #### First try with default settings

# %%
#Creating a plot (line graph) to show the number of action movies per year

plt.Figure(figsize=(10,6))
plt.plot(action_movies_per_year.index, action_movies_per_year.values, marker="o", color="orange")
plt.title("Number of Action Movies Released Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.grid(True)

plt.savefig('../plots/simple_action_movies_year.png')
plt.show()

# %% [markdown]
# ### Second try
# Making the plot more illustrative and easy to understand

# %%
# Devloping the figure more
years = action_movies_per_year.index
counts = action_movies_per_year.values

plt.figure(figsize=(12, 6))

# Plot the line
plt.plot(years, counts, color="#04A777", linestyle="-", linewidth=2, alpha=0.7)  # Light gray line

# Scatter plot with color scale
sc = plt.scatter(years, counts, c="#FB8B24", marker ="^", edgecolors="#CA2E55", s=50, zorder=3)  #choosing size of points, edges, color, marker (triangle) etc.

# Labels and grid
plt.title("Number of Action Movies Released Over Time", fontsize=14, fontweight="bold")
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Movies", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)

plt.savefig('../plots/Action_year.png')

plt.show()

# %% [markdown]
# ### Last try
# I want to create a smooth plot based on gausian filtering with the Scipy-library (module)

# %%
#Creating a smoother plot
from scipy.ndimage import gaussian_filter1d
from matplotlib.ticker import MaxNLocator #for integer numbers instead of decimals on the y-axis

# Sample data
years = action_movies_per_year.index
counts = action_movies_per_year.values

# Smooth the line using Gaussian filtering
smooth_counts = gaussian_filter1d(counts, sigma=2)

plt.figure(figsize=(12, 6))
plt.plot(years, smooth_counts, color="#FF5768", linewidth=3, label="Trend", alpha=0.8)
plt.fill_between(years, smooth_counts, color="#FB8B24", alpha=0.3)  # Adds a nice shaded effect

# Force integer values on the y-axis
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))

plt.title("Number of Action Movies Released Over Time", fontsize=14, fontweight="bold")
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Movies", fontsize=12)
plt.ylabel("Number of Movies", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()

#removes top, right and bottom line
sns.despine(left=False, bottom=False)

# Move the legend outside the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), borderaxespad=0., fontsize=14)


plt.savefig('../plots/Smooth_action_movies_year.png')

plt.show()

# %% [markdown]
# ### Conclusion
# The number of action movies is greater after year 2000, and looks like it has a downfall around year 2015.
